# %%
import pandas as pd

# %%
df = pd.read_csv('./raw_data/open_track2/raw_data.csv')
df.describe()
# Out:
#              game_id      action_id      period_id   time_seconds  \
# count  579306.000000  579306.000000  579306.000000  579306.000000
# mean   126380.236524    1468.650566       1.499301    1476.147922
# std        56.778999     855.439247       0.500000     891.317358
# min    126283.000000       0.000000       1.000000       0.000000
# 25%    126331.000000     731.000000       1.000000     697.500250
# 50%    126380.000000    1462.000000       1.000000    1453.450000
# 75%    126428.000000    2194.000000       2.000000    2241.325000
# max    126480.000000    3519.000000       2.000000    3614.467000
#
#              team_id      player_id        start_x        start_y  \
# count  579306.000000  579305.000000  579306.000000  579306.000000
# mean     3833.102607  333426.837096      52.792477      34.383346
# std      1377.857136  158692.532854      25.061882      20.303004
# min       316.000000   61616.000000       0.000000       0.000000
# ...

# %%
match_info_df = pd.read_csv('./raw_data/open_track2/match_info.csv')
match_info_df.head()
# Out:
#    game_id  season_id  competition_id  game_day            game_date  \
# 0   126283       3669             587         1  2024-03-01 05:00:00
# 1   126284       3669             587         1  2024-03-01 07:30:00
# 2   126285       3669             587         1  2024-03-02 05:00:00
# 3   126286       3669             587         1  2024-03-02 07:30:00
# 4   126287       3669             587         1  2024-03-02 07:30:00
#
#    home_team_id  away_team_id  home_score  away_score         venue  \
# 0          2354          4639           1           0      문수월드컵경기장
# 1          4640          4657           1           1      전주월드컵경기장
# 2          4648           316           2           0        광주전용구장
# 3          4646          4220           0           1     인천축구전용경기장
# 4          4643          4641           1           1  송암스포츠타운 주경기장
#
#   competition_name country_name  season_name          home_team_name  \
# ...

# %%
desc_df = pd.read_excel('./raw_data/open_track2/data_description.xlsx', engine='openpyxl')
desc_df.head()
# Out:
#       file_name            column_name                description data_type  \
# 0  raw_data.csv                game_id             경기를 구분하는 고유 ID     int64
# 1  raw_data.csv              action_id                경기 내 이벤트 순서     int64
# 2  raw_data.csv              period_id  전/후반 구분 (1: 전반, 2: 후반...)     int64
# 3  raw_data.csv           time_seconds      Period 시작 후 지난 시간 (초)   float64
# 4  raw_data.csv  relative_time_seconds             연관된 이벤트의 발생 시각   float64
#
#     notes
# 0     NaN
# 1  0부터 시작
# 2  1부터 시작
# 3     NaN
# 4     NaN
